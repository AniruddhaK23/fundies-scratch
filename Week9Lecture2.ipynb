# %% [markdown]
# <a href="https://colab.research.google.com/github/AniruddhaK23/fundies-scratch/blob/main/Week9Lecture2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    'day': ['mon','tues','wed','thurs','fri'],
    'max temp': [58, 62, 55, 59, 64]
}

# %%
temps = pd.DataFrame(data)

# %%
temps
# Out:
#      day  max temp
# 0    mon        58
# 1   tues        62
# 2    wed        55
# 3  thurs        59
# 4    fri        64

# %%
exercise = {
    'activity': ['Cardio','Push','Pull','Legs','Cardio'],
    'duration': [45,60,60,40,60]
}

workouts = pd.DataFrame(exercise)
workouts
# Out:
#   activity  duration
# 0   Cardio        45
# 1     Push        60
# 2     Pull        60
# 3     Legs        40
# 4   Cardio        60

# %%
photos = pd.read_csv('photos.csv')

# %%
photos.head()
# Out:
#                         Location   Subject        Date
# 0                   Cairo, Egypt  Portrait  2023-08-15
# 1                     London, UK  Mountain  2024-09-14
# 2                    Rome, Italy      Food  2021-10-14
# 3  Yellowstone National Park, WY   Concert  2024-05-31
# 4                   Tokyo, Japan      Food  2024-01-16

# %%
workouts.iloc[1]
# Out:
# activity    Push
# duration      60
# Name: 1, dtype: object

# %%
workouts['activity'].unique()
# Out:
# array(['Cardio', 'Push', 'Pull', 'Legs'], dtype=object)

# %%
workouts.iloc[2]['duration']
# Out:
# np.int64(60)

# %%
workouts['duration'][2]
# Out:
# np.int64(60)

# %%
workouts.iloc[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-91550989.py in <cell line: 0>()
# ----> 1 workouts.iloc[7]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1750
#    1751             # validate the location
# -> 1752             self._validate_integer(key, axis)
#    1753
#    1754             return self.obj._ixs(key, axis=axis)
#
# ...

# %%
workouts['workout']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'workout'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1486747834.py in <cell line: 0>()
# ----> 1 workouts['workout']
#
# ...
